# %% [markdown]
# # Exploratory Data Analysis
#
# ## Index:
# * [Understanding-data](#Understanding-data)
#  * [neighbourhood_overview](#neighbourhood_overview)
#  * [host_identity_verified](#host_identity_verified)
#  * [price](#price)
#  * [Neighbourhood](#neighbourhood)
#     * [Limpieza de datos](#limpieza_datos)
#     * [EDA con la variable neighbourhood](#eda_neighborhood)
# * [Second Bullet Header](#second-bullet)

# %% [markdown]
# ## Importing packages

# %%
import matplotlib.pylab as plt

import numpy as np
import pandas as pd7
import math
#import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

from pylab import *
import seaborn as sns
from scipy import stats

# %% [markdown]
# # Understanding / Cleaning the data <a class="anchor" id="Understanding-data"></a>

# %%
# download the data original
Airbnb_data = pd.read_csv('LosAngeles/listings_2.csv')
#make the price column into floats instead of strings
Airbnb_data['price'] = Airbnb_data['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# veiw the data
Airbnb_data.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   109   https://www.airbnb.com/rooms/109  20210807024723   2021-08-07
# 1  2708  https://www.airbnb.com/rooms/2708  20210807024723   2021-08-07
# 2  2732  https://www.airbnb.com/rooms/2732  20210807024723   2021-08-07
# 3  2864  https://www.airbnb.com/rooms/2864  20210807024723   2021-08-07
# 4  3021  https://www.airbnb.com/rooms/3021  20210807024723   2021-08-07
#
#                                                 name  \
# 0  Amazing bright elegant condo park front *UPGRA...
# 1  Runyon Canyon | Beau Furn Mirror Mini-Suite Fi...
# 2                              Zen Life at the Beach
# 3             * Beautiful Master Suite/Jacuzzi Tub/*
# 4    Hollywood Hills Zen Modern style Apt/Guesthouse
#
#                                          description  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  Run Runyon Canyon, Our Gym & Sauna Open <br />...
# 2  An oasis of tranquility awaits you.<br /><br /...
# 3  Centrally located.... Furnished with King Size...
# 4  A very Modern Hollywood Hills Zen style galler...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Walk and run to Runyon Canyon, it is open!<br ...
# 2  This is the best part of Santa Monica. Quiet, ...
# 3  What makes the neighborhood unique is that the...
# 4  This is the famous Hollywood hills.. Historica...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/4321499/1da98...      521
# 1  https://a0.muscache.com/pictures/miso/Hosting-...     3008
# 2  https://a0.muscache.com/pictures/1082974/0f74c...     3041
# 3  https://a0.muscache.com/pictures/23817858/de20...     3207
# 4  https://a0.muscache.com/pictures/5147dcd2-efad...     3415
#
#                                  host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/521  ...                        4.00
# 1  https://www.airbnb.com/users/show/3008  ...                        4.97
# 2  https://www.airbnb.com/users/show/3041  ...                        4.70
# 3  https://www.airbnb.com/users/show/3207  ...                         NaN
# 4  https://www.airbnb.com/users/show/3415  ...                        4.30
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   5.00                4.00     NaN                f
# 1                   5.00                4.84     NaN                t
# 2                   4.90                4.40  228269                f
# 3                    NaN                 NaN     NaN                t
# 4                   4.64                4.00     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              2                                           0
# 2                              2                                           1
# 3                              1                                           1
# 4                              4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            2
# 2                                            1
# 3                                            0
# 4                                            3
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.02
# 1                                           0              0.71
# 2                                           0              0.38
# 3                                           0               NaN
# 4                                           0              0.41
#
# [5 rows x 74 columns]

# %% [markdown]
# ### Data information

# %%
### Size
Airbnb_data.shape
# Out:
# (32240, 74)

# %%
# Columnas del dataframe
#Airbnb_data.columns

# %%
# statistic description
Airbnb_data.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.224000e+04  3.224000e+04  3.224000e+04         32199.000000
# mean   3.094821e+07  2.021081e+13  1.162544e+08            36.371626
# std    1.579977e+07  7.968874e-01  1.201506e+08           200.998227
# min    1.090000e+02  2.021081e+13  5.210000e+02             0.000000
# 25%    1.822399e+07  2.021081e+13  1.694717e+07             1.000000
# 50%    3.329885e+07  2.021081e+13  6.824693e+07             2.000000
# 75%    4.570328e+07  2.021081e+13  1.852758e+08             7.000000
# max    5.150898e+07  2.021081e+13  4.168894e+08          2232.000000
#
#        host_total_listings_count      latitude     longitude  accommodates  \
# count               32199.000000  32240.000000  32240.000000  32240.000000
# mean                   36.371626     34.048439   -118.319611      3.601427
# std                   200.998227      0.133991      0.165689      2.539507
# min                     0.000000     33.338480   -118.934830      0.000000
# 25%                     1.000000     33.996918   -118.423600      2.000000
# 50%                     2.000000     34.060310   -118.344650      3.000000
# 75%                     7.000000     34.104090   -118.252050      4.000000
# max                  2232.000000     34.811130   -117.653400     16.000000
#
#        bathrooms      bedrooms  ...  review_scores_cleanliness  \
# count        0.0  28531.000000  ...               23921.000000
# mean         NaN      1.665627  ...                   4.695832
# std          NaN      1.085385  ...                   0.506427
# min          NaN      1.000000  ...                   0.000000
# 25%          NaN      1.000000  ...                   4.620000
# 50%          NaN      1.000000  ...                   4.860000
# 75%          NaN      2.000000  ...                   5.000000
# max          NaN     15.000000  ...                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count           23911.000000                 23919.000000
# mean                4.846225                     4.830847
# std                 0.412591                     0.440036
# min                 0.000000                     0.000000
# 25%                 4.860000                     4.850000
# 50%                 4.970000                     4.970000
# 75%                 5.000000                     5.000000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value  \
# count            23908.000000         23906.000000
# mean                 4.802772             4.678927
# std                  0.399118             0.494423
# min                  0.000000             0.000000
# 25%                  4.770000             4.610000
# 50%                  4.920000             4.810000
# 75%                  5.000000             4.960000
# max                  5.000000             5.000000
#
#        calculated_host_listings_count  \
# count                    32240.000000
# mean                        12.926799
# std                         37.106482
# min                          1.000000
# 25%                          1.000000
# 50%                          2.000000
# 75%                          6.000000
# max                        306.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 32240.000000
# mean                                     10.285329
# std                                      35.622842
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       3.000000
# max                                     306.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  32240.000000
# mean                                       2.095596
# std                                       11.307134
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                      153.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 32240.000000        24271.00000
# mean                                      0.491191            2.08994
# std                                       4.438934            4.39220
# min                                       0.000000            0.01000
# 25%                                       0.000000            0.24000
# 50%                                       0.000000            0.89000
# 75%                                       0.000000            2.54000
# max                                      75.000000          185.00000
#
# [8 rows x 40 columns]

# %%
Airbnb_data.describe(include=['object'])
# Out:
#                              listing_url last_scraped             name  \
# count                              32240        32240            32238
# unique                             32240            2            31121
# top     https://www.airbnb.com/rooms/109   2021-08-07  Boutique Hostel
# freq                                   1        32236               75
#
#                                               description  \
# count                                               31082
# unique                                              28751
# top     <b>License number</b><br />Exempt - This listi...
# freq                                                   89
#
#                                     neighborhood_overview  \
# count                                               19789
# unique                                              16627
# top     The neighborhood of Sherman Oaks is a very aff...
# freq                                                  127
#
#                                               picture_url  \
# count                                               32240
# unique                                              30798
# top     https://a0.muscache.com/pictures/b8f67b03-6e16...
# freq                                                   75
#
#                                            host_url   host_name  host_since  \
# count                                         32240       32199       32199
# unique                                        18187        6994        3885
# top     https://www.airbnb.com/users/show/107434423  Blueground  2016-12-16
# freq                                            306         306         319
#
#                                  host_location  ...       property_type  \
# count                                    32126  ...               32240
# unique                                     974  ...                 104
# top     Los Angeles, California, United States  ...  Entire rental unit
# freq                                     13879  ...                8129
#
#               room_type bathrooms_text                    amenities  \
# count             32240          32182                        32240
# unique                4             48                        29201
# top     Entire home/apt         1 bath  ["Long term stays allowed"]
# freq              21719          14112                           88
#
#        has_availability calendar_last_scraped first_review last_review  \
# count             32240                 32240        24271       24271
# unique                2                     2         2879        2049
# top                   t            2021-08-07   2021-05-31  2021-08-01
# freq              31270                 32236           76         764
#
#                                                   license instant_bookable
# count                                                8011            32240
# unique                                               4435                2
# top     Exempt - This listing is a transient occupancy...                f
# freq                                                 1173            20908
#
# [4 rows x 34 columns]

# %%
Airbnb_data.hist(bins=50, figsize=(30,30))
plt.show()

# %% [markdown]
# ### Variables que vamos a ocupar:

# %%
Airbnb_data["neighbourhood_cleansed"]
# Out:
# 0                 Culver City
# 1                   Hollywood
# 2                Santa Monica
# 3                  Bellflower
# 4        Hollywood Hills West
#                  ...
# 32235                Downtown
# 32236               Los Feliz
# 32237           Beverly Grove
# 32238                Westwood
# 32239                Westwood
# Name: neighbourhood_cleansed, Length: 32240, dtype: object

# %%
new_Airbnb_data= Airbnb_data[['listing_url','name','description','neighborhood_overview', 
                          'picture_url','host_location', 'host_about','host_response_time', 'host_response_rate',
                          'host_acceptance_rate','host_is_superhost','host_picture_url','host_neighbourhood',
                          'host_has_profile_pic', 'host_identity_verified', 'neighbourhood_cleansed','latitude',
                          'longitude', 'property_type', 'room_type', 'accommodates', 
                          'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price','minimum_nights', 
                          'maximum_nights','number_of_reviews','first_review','last_review','review_scores_rating',
                          'review_scores_accuracy','review_scores_cleanliness', 'review_scores_checkin',
                          'review_scores_communication', 'review_scores_location','review_scores_value',
                          'reviews_per_month'
                         ]]
print("Número de variables: ",len(new_Airbnb_data.columns))
# Out:
# Número de variables:  39

# %%
new_Airbnb_data.head()
# Out:
#                          listing_url  \
# 0   https://www.airbnb.com/rooms/109
# 1  https://www.airbnb.com/rooms/2708
# 2  https://www.airbnb.com/rooms/2732
# 3  https://www.airbnb.com/rooms/2864
# 4  https://www.airbnb.com/rooms/3021
#
#                                                 name  \
# 0  Amazing bright elegant condo park front *UPGRA...
# 1  Runyon Canyon | Beau Furn Mirror Mini-Suite Fi...
# 2                              Zen Life at the Beach
# 3             * Beautiful Master Suite/Jacuzzi Tub/*
# 4    Hollywood Hills Zen Modern style Apt/Guesthouse
#
#                                          description  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  Run Runyon Canyon, Our Gym & Sauna Open <br />...
# 2  An oasis of tranquility awaits you.<br /><br /...
# 3  Centrally located.... Furnished with King Size...
# 4  A very Modern Hollywood Hills Zen style galler...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Walk and run to Runyon Canyon, it is open!<br ...
# 2  This is the best part of Santa Monica. Quiet, ...
# 3  What makes the neighborhood unique is that the...
# 4  This is the famous Hollywood hills.. Historica...
#
#                                          picture_url  \
# 0  https://a0.muscache.com/pictures/4321499/1da98...
# 1  https://a0.muscache.com/pictures/miso/Hosting-...
# 2  https://a0.muscache.com/pictures/1082974/0f74c...
# 3  https://a0.muscache.com/pictures/23817858/de20...
# 4  https://a0.muscache.com/pictures/5147dcd2-efad...
#
#                               host_location  \
# 0  San Francisco, California, United States
# 1    Los Angeles, California, United States
# 2   Santa Monica, California, United States
# 3     Bellflower, California, United States
# 4    Los Angeles, California, United States
#
#                                           host_about  host_response_time  \
# 0  Paolo Privitera, CEO Evensi\n\nPaolo, MIT MBA ...                 NaN
# 1  Writer.\r\nLiterary Manager.\r\nPhotographer.\...      within an hour
# 2  I have been teaching yoga and meditation for 3...      within an hour
# 3  Fair, open, honest and very informative for ne...                 NaN
# 4  Music Industry, Record producer, Songwriter, C...  within a few hours
#
#   host_response_rate host_acceptance_rate  ... first_review last_review  \
# 0                NaN                  NaN  ...   2011-08-15  2016-05-15
# 1               100%                 100%  ...   2017-12-29  2021-06-19
# 2               100%                  36%  ...   2017-01-13  2019-12-27
# 3                NaN                  NaN  ...          NaN         NaN
# 4               100%                  25%  ...   2017-01-03  2018-10-31
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                 4.00                   5.00                      5.00
# 1                 4.84                   4.77                      4.90
# 2                 4.68                   4.45                      4.57
# 3                  NaN                    NaN                       NaN
# 4                 4.04                   4.04                      3.83
#
#   review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                  3.00                         4.00                    5.00
# 1                  5.00                         4.97                    5.00
# 2                  4.65                         4.70                    4.90
# 3                   NaN                          NaN                     NaN
# 4                  3.96                         4.30                    4.64
#
#   review_scores_value reviews_per_month
# 0                4.00              0.02
# 1                4.84              0.71
# 2                4.40              0.38
# 3                 NaN               NaN
# 4                4.00              0.41
#
# [5 rows x 39 columns]

# %%
sns.heatmap(new_Airbnb_data.isnull(),yticklabels=False, cbar=False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
print("total de datos", new_Airbnb_data.shape[0], "\n")
print([new_Airbnb_data.isnull().sum()])
# Out:
# total de datos 32240
#
# [listing_url                        0
# name                               2
# description                     1158
# neighborhood_overview          12451
# picture_url                        0
# host_location                    114
# host_about                     12873
# host_response_time              8602
# host_response_rate              8602
# host_acceptance_rate            8401
# host_is_superhost                 41
# host_picture_url                  41
# host_neighbourhood              6296
# host_has_profile_pic              41
# host_identity_verified            41
# neighbourhood_cleansed             0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms_text                    58
# bedrooms                        3709
# beds                             638
# amenities                          0
# price                              0
# minimum_nights                     0
# maximum_nights                     0
# number_of_reviews                  0
# first_review                    7969
# last_review                     7969
# review_scores_rating            7969
# review_scores_accuracy          8320
# review_scores_cleanliness       8319
# review_scores_checkin           8329
# review_scores_communication     8321
# review_scores_location          8332
# review_scores_value             8334
# reviews_per_month               7969
# dtype: int64]

# %% [markdown]
# # Limpieza de datos  <a class="anchor" id="limpieza_datos"></a>

# %% [markdown]
# # Variables numericas

# %%
new_Airbnb_data.info()

#errores:
#8   host_response_rate           23638 non-null  object 
#9   host_acceptance_rate         23839 non-null  object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32240 entries, 0 to 32239
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listing_url                  32240 non-null  object
#  1   name                         32238 non-null  object
#  2   description                  31082 non-null  object
#  3   neighborhood_overview        19789 non-null  object
#  4   picture_url                  32240 non-null  object
#  5   host_location                32126 non-null  object
#  6   host_about                   19367 non-null  object
#  7   host_response_time           23638 non-null  object
#  8   host_response_rate           23638 non-null  object
#  9   host_acceptance_rate         23839 non-null  object
#  10  host_is_superhost            32199 non-null  object
#  11  host_picture_url             32199 non-null  object
#  12  host_neighbourhood           25944 non-null  object
#  13  host_has_profile_pic         32199 non-null  object
#  14  host_identity_verified       32199 non-null  object
#  15  neighbourhood_cleansed       32240 non-null  object
#  16  latitude                     32240 non-null  float64
#  17  longitude                    32240 non-null  float64
#  18  property_type                32240 non-null  object
#  19  room_type                    32240 non-null  object
#  20  accommodates                 32240 non-null  int64
#  21  bathrooms_text               32182 non-null  object
#  22  bedrooms                     28531 non-null  float64
#  23  beds                         31602 non-null  float64
#  24  amenities                    32240 non-null  object
#  25  price                        32240 non-null  float64
#  26  minimum_nights               32240 non-null  int64
#  27  maximum_nights               32240 non-null  int64
#  28  number_of_reviews            32240 non-null  int64
#  29  first_review                 24271 non-null  object
#  30  last_review                  24271 non-null  object
#  31  review_scores_rating         24271 non-null  float64
#  32  review_scores_accuracy       23920 non-null  float64
#  33  review_scores_cleanliness    23921 non-null  float64
#  34  review_scores_checkin        23911 non-null  float64
#  35  review_scores_communication  23919 non-null  float64
#  36  review_scores_location       23908 non-null  float64
#  37  review_scores_value          23906 non-null  float64
#  38  reviews_per_month            24271 non-null  float64
# dtypes: float64(13), int64(4), object(22)
# memory usage: 9.6+ MB

# %%
# cambiar rates a numeros entre 0 y 1 new_Airbnb_data[[ 'host_response_rate','host_acceptance_rate']]

def remove_porc(num):
    num = str(num).replace("%","")
    return float(num)

def convert_decimal(num):
    num = float(num)/100
    return num

serie = new_Airbnb_data.host_response_rate.apply(remove_porc)
new_Airbnb_data["host_response_rate"] = serie
serie2 = new_Airbnb_data.host_response_rate.apply(convert_decimal)
new_Airbnb_data["host_response_rate"] = serie2

serie = new_Airbnb_data.host_response_rate.apply(remove_porc)
new_Airbnb_data["host_acceptance_rate"] = serie
serie2 = new_Airbnb_data.host_response_rate.apply(convert_decimal)
new_Airbnb_data["host_acceptance_rate"] = serie2

new_Airbnb_data[['host_response_rate','host_acceptance_rate']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32240 entries, 0 to 32239
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   host_response_rate    23638 non-null  float64
#  1   host_acceptance_rate  23638 non-null  float64
# dtypes: float64(2)
# memory usage: 503.9 KB
# /tmp/ipykernel_29564/835962615.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_Airbnb_data["host_response_rate"] = serie
# /tmp/ipykernel_29564/835962615.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_Airbnb_data["host_response_rate"] = serie2
# /tmp/ipykernel_29564/835962615.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_Airbnb_data["host_acceptance_rate"] = serie
# /tmp/ipykernel_29564/835962615.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_Airbnb_data["host_acceptance_rate"] = serie2

# %% [markdown]
# # Reemplazo de nulos:

# %%
#new_Airbnb_data[['neighbourhood','property_type','room_type','host_has_profile_pic','host_identity_verified','correct_neighbourhood_cleansed','review_scores_rating', 'host_response_rate','host_acceptance_rate', 'bedrooms', 'beds', 'price','minimum_nights', 
 #                         'maximum_nights','number_of_reviews','beds']]
sns.heatmap(new_Airbnb_data[['review_scores_rating', 'host_response_rate','host_acceptance_rate', 'bedrooms', 
                             'beds', 'price','minimum_nights', 
                          'maximum_nights','number_of_reviews','review_scores_cleanliness',
                             'review_scores_accuracy','review_scores_checkin',
                                  'review_scores_communication','review_scores_location',
                             'review_scores_value','reviews_per_month']].isnull(),yticklabels=False, cbar=False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
lista_varibales = ['review_scores_rating', 'host_response_rate','host_acceptance_rate', 'bedrooms', 
                             'beds', 'price','minimum_nights', 
                          'maximum_nights','number_of_reviews','review_scores_cleanliness',
                             'review_scores_accuracy','review_scores_checkin',
                                  'review_scores_communication','review_scores_location',
                             'review_scores_value','reviews_per_month']
def obtain_num_nulos(lista):
    lista_var_nulas =[]
    for elem in lista:
        if new_Airbnb_data[elem].isnull().sum() > 0:
            lista_var_nulas.append(elem)
            print("nulos total ",elem,":", new_Airbnb_data[elem].isnull().sum())
    return lista_var_nulas
lista_var_nulas = obtain_num_nulos(lista_varibales_nulas)
# Out:
# nulos total  review_scores_rating : 7969
# nulos total  host_response_rate : 8602
# nulos total  host_acceptance_rate : 8602
# nulos total  bedrooms : 3709
# nulos total  beds : 638
# nulos total  review_scores_cleanliness : 8319
# nulos total  review_scores_accuracy : 8320
# nulos total  review_scores_checkin : 8329
# nulos total  review_scores_communication : 8321
# nulos total  review_scores_location : 8332
# nulos total  review_scores_value : 8334
# nulos total  reviews_per_month : 7969

# %%
def obtain_mean(lista):
    means = []
    for elem in lista:
        means.append(new_Airbnb_data[elem].mean(axis=0))
    return means

# %%
means = obtain_mean(lista_var_nulas)

lista_mean_variable = list(zip(lista_var_nulas,means))
lista_mean_variable

for var,elem in zip(lista_var_nulas,means):
    print(var)
    print(elem)
# Out:
# review_scores_rating
# 4.663436611594125
# host_response_rate
# 0.9098493950418874
# host_acceptance_rate
# 0.00909849395041744
# bedrooms
# 1.6656268620097439
# beds
# 1.964400987279286
# review_scores_cleanliness
# 4.695832114042097
# review_scores_accuracy
# 4.772647157190698
# review_scores_checkin
# 4.846224750115052
# review_scores_communication
# 4.830847025377369
# review_scores_location
# 4.802772293792919
# review_scores_value
# 4.678926629298121
# reviews_per_month
# 2.089939845906646

# %%
avg_bedrooms = lista_mean_variable[3][1]
avg_beds = lista_mean_variable[4][1]
print("promedio de bedrooms con decimales:",avg_bedrooms)
avg_bedrooms = math.ceil(avg_bedrooms)
print("promedio de beds con decimales:",avg_beds)
avg_beds = math.ceil(avg_beds)
print("promedio de bedrooms con decimales:",avg_bedrooms)
print("promedio de beds con decimales:",avg_beds)
# Out:
# promedio de bedrooms con decimales: 1.6656268620097439
# promedio de beds con decimales: 1.964400987279286
# promedio de bedrooms con decimales: 2
# promedio de beds con decimales: 2

# %%
lista_var_nulas = obtain_num_nulos(lista_varibales_nulas)
means = obtain_mean(lista_var_nulas)
lista_mean_variable = list(zip(lista_var_nulas,means))
lista_mean_variable
# Out:
# nulos total  review_scores_rating : 7969
# nulos total  host_response_rate : 8602
# nulos total  host_acceptance_rate : 8602
# nulos total  bedrooms : 3709
# nulos total  beds : 638
# nulos total  review_scores_cleanliness : 8319
# nulos total  review_scores_accuracy : 8320
# nulos total  review_scores_checkin : 8329
# nulos total  review_scores_communication : 8321
# nulos total  review_scores_location : 8332
# nulos total  review_scores_value : 8334
# nulos total  reviews_per_month : 7969
# [('review_scores_rating', 4.663436611594125),
#  ('host_response_rate', 0.9098493950418874),
#  ('host_acceptance_rate', 0.00909849395041744),
#  ('bedrooms', 1.6656268620097439),
#  ('beds', 1.964400987279286),
#  ('review_scores_cleanliness', 4.695832114042097),
#  ('review_scores_accuracy', 4.772647157190698),
#  ('review_scores_checkin', 4.846224750115052),
#  ('review_scores_communication', 4.830847025377369),
#  ('review_scores_location', 4.802772293792919),
#  ('review_scores_value', 4.678926629298121),
#  ('reviews_per_month', 2.089939845906646)]

# %%
new_Airbnb_data["bedrooms"].replace(np.nan, avg_bedrooms, inplace=True)
new_Airbnb_data["beds"].replace(np.nan, avg_beds, inplace=True)
# Out:
# /home/rebeca/miniconda3/envs/mineros/lib/python3.9/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
def reemplazar_nulos(lista_var_nulas,lista_means):
    for var,elem in zip(lista_var_nulas,lista_means):
        new_Airbnb_data[var].replace(np.nan, elem, inplace=True)

# %%
reemplazar_nulos(lista_var_nulas,means)

# %%
#verificamos que queden nulos
obtain_num_nulos(lista_varibales_nulas)
# Out:
# []

# %%
fig = plt.gcf()
# Change seaborn plot size
fig.set_size_inches(6, 4)
sns.scatterplot(data=new_Airbnb_data, x="review_scores_rating", y="host_has_profile_pic", hue="host_has_profile_pic",style="host_has_profile_pic")
# Out:
# <AxesSubplot:xlabel='review_scores_rating', ylabel='host_has_profile_pic'>

# %%
fig = plt.gcf()
# Change seaborn plot size
fig.set_size_inches(6, 4)
sns.scatterplot(data=new_Airbnb_data, x="review_scores_rating", y="host_identity_verified", hue="host_identity_verified",style="host_identity_verified")
# Out:
# <AxesSubplot:xlabel='review_scores_rating', ylabel='host_identity_verified'>

# %%
fig = plt.gcf()
# Change seaborn plot size
fig.set_size_inches(6, 4)
sns.scatterplot(data=new_Airbnb_data, x="review_scores_rating", y="host_is_superhost", hue="host_is_superhost",style="host_is_superhost")
# Out:
# <AxesSubplot:xlabel='review_scores_rating', ylabel='host_is_superhost'>

# %%
new_Airbnb_data["host_has_profile_pic"].replace(np.nan, 'f', inplace=True)
new_Airbnb_data["host_identity_verified"].replace(np.nan, 'f', inplace=True)
new_Airbnb_data["host_is_superhost"].replace(np.nan, 'f', inplace=True)
# Out:
# /home/rebeca/miniconda3/envs/mineros/lib/python3.9/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
new_Airbnb_data["host_is_superhost"].unique()
# Out:
# array(['f', 't'], dtype=object)

# %%
#verificamos cuantos nulos (que nos importan) quedan
obtain_num_nulos(list(new_Airbnb_data.columns))
# Out:
# nulos total  name : 2
# nulos total  description : 1158
# nulos total  neighborhood_overview : 12451
# nulos total  host_location : 114
# nulos total  host_about : 12873
# nulos total  host_response_time : 8602
# nulos total  host_picture_url : 41
# nulos total  host_neighbourhood : 6296
# nulos total  bathrooms_text : 58
# nulos total  first_review : 7969
# nulos total  last_review : 7969
# ['name',
#  'description',
#  'neighborhood_overview',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_picture_url',
#  'host_neighbourhood',
#  'bathrooms_text',
#  'first_review',
#  'last_review']

# %% [markdown]
# # neighbourhood <a class="anchor" id="neighbourhood"></a>

# %%
print("\ntotal de valores nulos en Neighbourhood: ",new_Airbnb_data['neighbourhood_cleansed'].isnull().sum())
print("\ntotal de valores nulos en latitude: ",new_Airbnb_data['latitude'].isnull().sum())
print("\ntotal de valores nulos en longitude: ",new_Airbnb_data['longitude'].isnull().sum())
# Out:
# total de valores nulos en Neighbourhood:  0
#
# total de valores nulos en latitude:  0
#
# total de valores nulos en longitude:  0

# %%
# ya categorizamos correctamente las ciudades
city_counts = pd.DataFrame(new_Airbnb_data.groupby(['neighbourhood_cleansed']).size())
city_counts.columns=["size"]
city_counts
# Out:
#                         size
# neighbourhood_cleansed
# Acton                      4
# Adams-Normandie           32
# Agoura Hills              47
# Agua Dulce                19
# Alhambra                 326
# ...                      ...
# Willowbrook               23
# Wilmington                32
# Windsor Square            31
# Winnetka                  75
# Woodland Hills           262
#
# [264 rows x 1 columns]

# %%
city_counts.insert(0,"neighbourhood_cleansed",list(city_counts.index.values))

# %%
city_counts = city_counts.sort_values(by=['size'])
city_counts
# Out:
#                        neighbourhood_cleansed  size
# neighbourhood_cleansed
# Hawaiian Gardens             Hawaiian Gardens     1
# Chatsworth Reservoir     Chatsworth Reservoir     1
# Leona Valley                     Leona Valley     1
# Cudahy                                 Cudahy     1
# East Compton                     East Compton     1
# ...                                       ...   ...
# Downtown                             Downtown  1028
# Santa Monica                     Santa Monica  1091
# Long Beach                         Long Beach  1340
# Hollywood                           Hollywood  1574
# Venice                                 Venice  1600
#
# [264 rows x 2 columns]

# %%
# pasar un nuevo index
s = pd.Series(list(range(0,264)))
city_counts=city_counts.set_index([s])

# %%
city_counts.tail(5)
# Out:
#     neighbourhood_cleansed  size
# 259               Downtown  1028
# 260           Santa Monica  1091
# 261             Long Beach  1340
# 262              Hollywood  1574
# 263                 Venice  1600

# %% [markdown]
# # property_type

# %%
property_type = pd.DataFrame(new_Airbnb_data.groupby(['property_type'],as_index=False).size())
property_type = property_type.sort_values(by=['size'])
property_type
# Out:
#                        property_type  size
# 51             Private room in minsu     1
# 49            Private room in island     1
# 29                        Lighthouse     1
# 27                        Hotel room     1
# 63                Religious building     1
# ..                               ...   ...
# 14                 Entire guesthouse  1801
# 52       Private room in rental unit  2161
# 53  Private room in residential home  4498
# 19           Entire residential home  5860
# 18                Entire rental unit  8129
#
# [104 rows x 2 columns]

# %%
property_type.tail(10)
# Out:
#                           property_type  size
# 40  Private room in condominium (condo)   562
# 21            Entire serviced apartment   573
# 8                       Entire bungalow   602
# 13                   Entire guest suite  1080
# 11           Entire condominium (condo)  1585
# 14                    Entire guesthouse  1801
# 52          Private room in rental unit  2161
# 53     Private room in residential home  4498
# 19              Entire residential home  5860
# 18                   Entire rental unit  8129

# %% [markdown]
# # room_type

# %%
room_type = pd.DataFrame(new_Airbnb_data.groupby(['room_type'],as_index=False).size())
room_type = room_type.sort_values(by=['size'])
room_type
# Out:
#          room_type   size
# 1       Hotel room    112
# 3      Shared room    948
# 2     Private room   9461
# 0  Entire home/apt  21719

# %% [markdown]
# # accomodates

# %%
accomodates = pd.DataFrame(new_Airbnb_data.groupby(['accommodates'],as_index=False).size())
accomodates = accomodates.sort_values(by=['size'])
accomodates.tail()
# Out:
#    accommodates   size
# 3             3   3006
# 6             6   3019
# 1             1   3824
# 4             4   5683
# 2             2  11861

# %%
fig = plt.gcf()
# Change seaborn plot size
fig.set_size_inches(8, 8)
#sns.histplot(data=new_Airbnb_data, x='host_identity_verified',palette = sns.color_palette("tab10"),alpha = 1,shrink=.8)
sns.histplot(data=new_Airbnb_data, x="host_identity_verified", hue="host_identity_verified")
# Out:
# <AxesSubplot:xlabel='host_identity_verified', ylabel='Count'>

# %%
new_Airbnb_data[['review_scores_rating',
                          'review_scores_accuracy','review_scores_cleanliness', 'review_scores_checkin',
                          'review_scores_communication', 'review_scores_location','review_scores_value',
                          'reviews_per_month'
                         ]].describe()
# Out:
#        review_scores_rating  review_scores_accuracy  \
# count          32240.000000            32240.000000
# mean               4.663437                4.772647
# std                0.623040                0.403236
# min                0.000000                0.000000
# 25%                4.663437                4.772647
# 50%                4.750000                4.820000
# 75%                4.960000                4.990000
# max                5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count               32240.000000           32240.000000
# mean                    4.695832               4.846225
# std                     0.436221               0.355319
# min                     0.000000               0.000000
# 25%                     4.695832               4.846225
# 50%                     4.710000               4.910000
# 75%                     4.950000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                 32240.000000            32240.000000
# mean                      4.830847                4.802772
# std                       0.379018                0.343695
# min                       0.000000                0.000000
# 25%                       4.830847                4.802772
# 50%                       4.900000                4.830000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  reviews_per_month
# count         32240.000000       32240.000000
# mean              4.678927           2.089940
# std               0.425748           3.810888
# min               0.000000           0.010000
# 25%               4.678927           0.380000
# 50%               4.680000           1.810000
# 75%               4.900000           2.089940
# max               5.000000         185.000000

# %%
new_Airbnb_data[[ 'host_response_rate','host_acceptance_rate', 'bedrooms', 'beds', 'amenities', 'price','minimum_nights', 
                          'maximum_nights','number_of_reviews'
                         ]].describe()
# Out:
#        host_response_rate  host_acceptance_rate      bedrooms          beds  \
# count        32240.000000          32240.000000  32240.000000  32240.000000
# mean             0.909849              0.009098      1.704094      1.965105
# std              0.193348              0.001933      1.026602      1.536892
# min              0.000000              0.000000      1.000000      0.000000
# 25%              0.909849              0.009098      1.000000      1.000000
# 50%              0.990000              0.009900      1.000000      1.000000
# 75%              1.000000              0.010000      2.000000      2.000000
# max              1.000000              0.010000     15.000000     26.000000
#
#               price  minimum_nights  maximum_nights  number_of_reviews
# count  32240.000000    32240.000000    32240.000000       32240.000000
# mean     266.104622       20.317246      664.483623          33.930490
# std      729.862325       34.120765      506.685023          68.118577
# min        0.000000        1.000000        1.000000           0.000000
# 25%       75.750000        2.000000       90.000000           1.000000
# 50%      125.000000       30.000000     1125.000000           6.000000
# 75%      226.000000       30.000000     1125.000000          34.000000
# max    25000.000000     1125.000000    10000.000000         915.000000

# %%
new_Airbnb_data["neighbourhood_cleansed"].value_counts().idxmax()
# Out:
# 'Venice'

# %%
catalogo_County=pd.read_csv("LosAngeles/Los_Angeles_County_Dataset.csv")
catalogo_County.head()
# Out:
#         County           Region               Neighborhood
# 0  Los Angeles   Angeles Forest              Angeles Crest
# 1  Los Angeles   Angeles Forest            Tujunga Canyons
# 2  Los Angeles  Antelope Valley  Northwest Antelope Valley
# 3  Los Angeles  Antelope Valley               Leona Valley
# 4  Los Angeles  Antelope Valley                   Palmdale

# %%
# lista con los neighbourhood correctos
list(new_Airbnb_data["neighbourhood_cleansed"].unique())[0:11]
# Out:
# ['Culver City',
#  'Hollywood',
#  'Santa Monica',
#  'Bellflower',
#  'Hollywood Hills West',
#  'Del Rey',
#  'Atwater Village',
#  'Long Beach',
#  'Venice',
#  'Mid-Wilshire',
#  'Gardena']

# %% [markdown]
# # Bedrooms

# %%
bedrooms = pd.DataFrame(new_Airbnb_data.groupby(['bedrooms'],as_index=False).size())
bedrooms = bedrooms.sort_values(by=['size'])
bedrooms
# Out:
#     bedrooms   size
# 10      11.0      1
# 12      13.0      1
# 13      15.0      1
# 11      12.0      2
# 9       10.0      4
# 8        9.0     10
# 7        8.0     23
# 6        7.0     67
# 5        6.0    171
# 4        5.0    507
# 3        4.0   1272
# 2        3.0   2838
# 1        2.0   9588
# 0        1.0  17755

# %%
new_Airbnb_data['bedrooms'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Host_Response_rate and host_acceptance_rate

# %%
new_Airbnb_data[['host_response_rate','host_acceptance_rate']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32240 entries, 0 to 32239
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   host_response_rate    32240 non-null  float64
#  1   host_acceptance_rate  32240 non-null  float64
# dtypes: float64(2)
# memory usage: 503.9 KB

# %%
# cambiar tipo de dato a numero entre 0 y 1
new_Airbnb_data[[ 'host_response_rate','host_acceptance_rate']]
# Out:
#        host_response_rate  host_acceptance_rate
# 0                0.909849              0.009098
# 1                1.000000              0.010000
# 2                1.000000              0.010000
# 3                0.909849              0.009098
# 4                1.000000              0.010000
# ...                   ...                   ...
# 32235            0.700000              0.007000
# 32236            0.700000              0.007000
# 32237            0.940000              0.009400
# 32238            1.000000              0.010000
# 32239            1.000000              0.010000
#
# [32240 rows x 2 columns]

# %%
print("\ntotal de valores nulos en host_response_rate: ",new_Airbnb_data['host_response_rate'].isnull().sum())
#pd.to_numeric(new_Airbnb_data['host_response_rate'])
print("\ntotal de valores nulos en host_acceptance_rate: ",new_Airbnb_data['host_acceptance_rate'].isnull().sum())
# Out:
# total de valores nulos en host_response_rate:  0
#
# total de valores nulos en host_acceptance_rate:  0

# %%
new_Airbnb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32240 entries, 0 to 32239
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listing_url                  32240 non-null  object
#  1   name                         32238 non-null  object
#  2   description                  31082 non-null  object
#  3   neighborhood_overview        19789 non-null  object
#  4   picture_url                  32240 non-null  object
#  5   host_location                32126 non-null  object
#  6   host_about                   19367 non-null  object
#  7   host_response_time           23638 non-null  object
#  8   host_response_rate           32240 non-null  float64
#  9   host_acceptance_rate         32240 non-null  float64
#  10  host_is_superhost            32240 non-null  object
#  11  host_picture_url             32199 non-null  object
#  12  host_neighbourhood           25944 non-null  object
#  13  host_has_profile_pic         32240 non-null  object
#  14  host_identity_verified       32240 non-null  object
#  15  neighbourhood_cleansed       32240 non-null  object
#  16  latitude                     32240 non-null  float64
#  17  longitude                    32240 non-null  float64
#  18  property_type                32240 non-null  object
#  19  room_type                    32240 non-null  object
#  20  accommodates                 32240 non-null  int64
#  21  bathrooms_text               32182 non-null  object
#  22  bedrooms                     32240 non-null  float64
#  23  beds                         32240 non-null  float64
#  24  amenities                    32240 non-null  object
#  25  price                        32240 non-null  float64
#  26  minimum_nights               32240 non-null  int64
#  27  maximum_nights               32240 non-null  int64
#  28  number_of_reviews            32240 non-null  int64
#  29  first_review                 24271 non-null  object
#  30  last_review                  24271 non-null  object
#  31  review_scores_rating         32240 non-null  float64
#  32  review_scores_accuracy       32240 non-null  float64
#  33  review_scores_cleanliness    32240 non-null  float64
#  34  review_scores_checkin        32240 non-null  float64
#  35  review_scores_communication  32240 non-null  float64
#  36  review_scores_location       32240 non-null  float64
#  37  review_scores_value          32240 non-null  float64
#  38  reviews_per_month            32240 non-null  float64
# dtypes: float64(15), int64(4), object(20)
# memory usage: 9.6+ MB

# %% [markdown]
# # host_identity_verified <a class="anchor" id="host_identity_verified"></a>

# %%
new_Airbnb_data["host_identity_verified"].isnull().sum()
# Out:
# 0

# %%
verified_count = new_Airbnb_data.groupby('host_identity_verified')['host_identity_verified'].count()
verified_count
# Out:
# host_identity_verified
# f     5803
# t    26437
# Name: host_identity_verified, dtype: int64

# %%
# distribution
sns.countplot(x='host_identity_verified', data=new_Airbnb_data)
plt.show()

# %% [markdown]
# # price <a class="anchor" id="price"></a>

# %%
# view a histogram of the prices
fig, ax = plt.subplots()
n, bins, patches = ax.hist(new_Airbnb_data.price, 50)
ax.set_xlabel('precio')
ax.set_ylabel('frecuencia')
ax.set_title(r'Precio de renta')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()

# %%
new_Airbnb_data.price.describe()
# Out:
# count    32240.000000
# mean       266.104622
# std        729.862325
# min          0.000000
# 25%         75.750000
# 50%        125.000000
# 75%        226.000000
# max      25000.000000
# Name: price, dtype: float64

# %%
print("numero de datos con precio 25000:",len(new_Airbnb_data[(new_Airbnb_data.price == 25000)]))
print("numero de datos con precio 0:",len(new_Airbnb_data[(new_Airbnb_data.price == 0)]))
print("\n max price info:\n")
print(new_Airbnb_data[(new_Airbnb_data.price == 25000)].neighbourhood_cleansed)
print("\n min price info:\n")
print(new_Airbnb_data[(new_Airbnb_data.price == 0)].neighbourhood_cleansed)
# Out:
# numero de datos con precio 25000: 6
# numero de datos con precio 0: 16
#
#  max price info:
#
# 27668    Beverly Hills
# 27691    Beverly Hills
# 27692    Beverly Hills
# 27694    Beverly Hills
# 27695    Beverly Hills
# 27696    Beverly Hills
# Name: neighbourhood_cleansed, dtype: object
#
#  min price info:
#
# 20265          Hollywood
# 20266          Koreatown
# 21031             Venice
# 21329        Studio City
# 21330        Studio City
# 21366       Santa Monica
# 21427      Beverly Hills
# 21762           Westwood
# 21763           Glendale
# 21982          Hollywood
# 22106         West Adams
# 22107          Koreatown
# 22108          Koreatown
# 22109    North Hollywood
# 24944     West Hollywood
# 24952       Santa Monica
# Name: neighbourhood_cleansed, dtype: object

# %% [markdown]
# <div class = "alert alert-danger">
#     <h3>Notas:</h3>
# <br>
# <dl>
#     <dt> El precio máximo es 25,000 </dt>
#     <dd> - el número de datos con este precio son 6 </dd>
#     <dt>El precio mínimo 0 </dt>
# </dl>
# </div>

# %%
# obtain more info from bins of histogram
def bins_info(patches):
    C  = []
    for i in range(0,len(patches)):
        C.append(patches[i].get_xy()[0])
    dic = {f"[{C[i]},{C[i+1]})": patches[i].get_height() for i in range(len(patches)-1)}
    dic[f"[{C[-1]},{C[-1]+patches[-1].get_width()})"]= patches[-1].get_height()
    return dic

fig, ax = plt.subplots()
n, bins, patches = ax.hist(new_Airbnb_data.price, 50)
p = ax.patches
C = bins_info(p)
pd.DataFrame(C.items(),columns = ['bins','frecuency']).head()
# Out:
#               bins  frecuency
# 0      [0.0,500.0)    29423.0
# 1   [500.0,1000.0)     1618.0
# 2  [1000.0,1500.0)      440.0
# 3  [1500.0,2000.0)      265.0
# 4  [2000.0,2500.0)      119.0

# %%
#Clean data
# if the price is less then 5 and greater than 2,000 revome it 
new_Airbnb_data = new_Airbnb_data[(new_Airbnb_data.price > 5) & (new_Airbnb_data.price <= 4000)]

# %%
fig, ax = plt.subplots()
ax.set_xlabel('precio')
ax.set_ylabel('frecuencia')
ax.set_title(r'Precio de renta')
new_Airbnb_data.price.hist(bins=50, figsize=(10,7))
plt.show()

# %%
new_Airbnb_data.price.describe()
# Out:
# count    32058.000000
# mean       226.143584
# std        357.481028
# min         10.000000
# 25%         75.000000
# 50%        125.000000
# 75%        225.000000
# max       4000.000000
# Name: price, dtype: float64

# %%
print("\ntotal de valores nulos en price: ",new_Airbnb_data['price'].isnull().sum())
# Out:
# total de valores nulos en price:  0

# %%
fig = plt.gcf()
# Change seaborn plot size
fig.set_size_inches(12, 8)
sns.histplot(data=new_Airbnb_data, x="price", kde=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# # Matriz de correlación

# %%
new_Airbnb_data1 = new_Airbnb_data[[ 'host_response_rate','host_acceptance_rate', 'bedrooms', 'beds', 'amenities', 'price','minimum_nights', 
                          'maximum_nights','number_of_reviews'
                         ]]
f, ax = plt.subplots(figsize=(10,10))
sns.heatmap(new_Airbnb_data1.corr(), annot=True, linewidths = .5, fmt='.1f', ax = ax)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x = 'price', y = "host_is_superhost", data=new_Airbnb_data, hue="host_is_superhost",palette="Set3")
# Out:
# <AxesSubplot:xlabel='price', ylabel='host_is_superhost'>

# %%
new_Airbnb_data.boxplot(column = 'price', by = 'host_identity_verified')
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='host_identity_verified'>

# %%
new_Airbnb_data.plot(kind = "scatter", x = "beds",y = "price")
# Out:
# <AxesSubplot:xlabel='beds', ylabel='price'>

# %%
new_Airbnb_data.plot(kind = "scatter", x = "review_scores_rating", y= "price")
# Out:
# <AxesSubplot:xlabel='review_scores_rating', ylabel='price'>

# %% [markdown]
# # Review_scores_rating

# %%
new_Airbnb_data["review_scores_rating"].isnull().sum()
# Out:
# 0

# %%
avg_review_rating = new_Airbnb_data["review_scores_rating"].mean(axis=0)
print("promedio de review_scores_rating:",avg_review_rating)
# Out:
# promedio de review_scores_rating: 4.663935812409337

# %%
fig = plt.gcf()
# Change seaborn plot size
fig.set_size_inches(6, 4)
sns.scatterplot(data=new_Airbnb_data, x="number_of_reviews", y="price")
# Out:
# <AxesSubplot:xlabel='number_of_reviews', ylabel='price'>

# %%
fig = plt.gcf()
# Change seaborn plot size
fig.set_size_inches(6, 4)
sns.scatterplot(data=new_Airbnb_data, x="review_scores_rating", y="price", hue="host_is_superhost",style="host_is_superhost")
# Out:
# <AxesSubplot:xlabel='review_scores_rating', ylabel='price'>

# %% [markdown]
# # Antiguedad

# %%
new_Airbnb_data_dates = new_Airbnb_data.copy()
new_Airbnb_data_dates['calendar_last_scrape']="2021-08-07"
new_Airbnb_data_dates= new_Airbnb_data_dates[~new_Airbnb_data_dates.last_review.isnull()]
new_Airbnb_data_dates= new_Airbnb_data_dates[~new_Airbnb_data_dates.first_review.isnull()]

# %%
new_Airbnb_data_dates["first_review"]
# Out:
# 0        2011-08-15
# 1        2017-12-29
# 2        2017-01-13
# 4        2017-01-03
# 5        2015-11-29
#             ...
# 31739    2021-08-01
# 31770    2021-08-06
# 31772    2021-08-02
# 31868    2021-08-03
# 31947    2021-08-05
# Name: first_review, Length: 24206, dtype: object

# %%
from datetime import date, timedelta
current_date = date.today()
current_date
#Airbnb lanzada en 2008
# Out:
# datetime.date(2021, 9, 23)

# %%
def convert_date(dato):
    if(dato.find("/") > 0):
        l1 =str(dato).split("/")
        #l1.append('20'+l1.pop())
        #l2 = list(map(int,l1))
    else:
        l1 =str(dato).split("-")
        #l1.append('20'+l1.pop())
        #l2 = list(map(int,l1))
    year = int(l1[0])
    month=int(l1[1])
    day = int(l1[2])
    return date(year, month,day)

def convert_to_date(dato):
    dato = dato.replace("days, 0:00:00","").strip()
    dato = dato.replace("day, 0:00:00","").strip()
    dato = dato.replace('0:00:00',"0").strip()
    #dato = dato.replace("''","").strip()
    #dato = dato.replace("day, 0:00:00","").strip()
    return int(dato)

def antiguedad(first_review,last_scrape):
    last_scrape= convert_date(last_scrape)
    first_review=convert_date(first_review)
    dato = last_scrape-first_review
    dato = convert_to_date(str(dato))
    return dato

def dias_transcurridos_last_review(last_review,last_scrape):
    last_scrape= convert_date(last_scrape)
    last_review=convert_date(last_review)
    dato = last_scrape-last_review
    dato = convert_to_date(str(dato))
    return dato

# %%
first_review = list(new_Airbnb_data_dates.first_review)
#first_review
antiguedad_relativa=list(map(lambda x:antiguedad(x,last_scrape ="2021-08-07"),first_review))
df_ant_rel = pd.DataFrame(antiguedad_relativa,columns=['days_of_relative_antiquity'])

# %%
last_review = list(new_Airbnb_data_dates.last_review)
days_past_from_lastreview=list(map(lambda x:dias_transcurridos_last_review(x,last_scrape ="2021-08-07"),last_review))
df_last_rev = pd.DataFrame(days_past_from_lastreview,columns=['days_past_from_lastreview'])

# %%
df_reviews_days=df_ant_rel.join(df_last_rev.days_past_from_lastreview)
#preguntar si tenemos variables nulas
print(df_reviews_days.isnull().sum())
# Out:
# days_of_relative_antiquity    0
# days_past_from_lastreview     0
# dtype: int64

# %%
df_reviews_days
# Out:
#        days_of_relative_antiquity  days_past_from_lastreview
# 0                            3645                       1910
# 1                            1317                         49
# 2                            1667                        589
# 3                            1677                       1011
# 4                            2078                          7
# ...                           ...                        ...
# 24201                           6                          6
# 24202                           1                          1
# 24203                           5                          5
# 24204                           4                          4
# 24205                           2                          2
#
# [24206 rows x 2 columns]

# %%
new_Airbnb_data_dates = new_Airbnb_data_dates.join(df_reviews_days)
new_Airbnb_data_dates.head()
# Out:
#                          listing_url  \
# 0   https://www.airbnb.com/rooms/109
# 1  https://www.airbnb.com/rooms/2708
# 2  https://www.airbnb.com/rooms/2732
# 4  https://www.airbnb.com/rooms/3021
# 5  https://www.airbnb.com/rooms/5728
#
#                                                 name  \
# 0  Amazing bright elegant condo park front *UPGRA...
# 1  Runyon Canyon | Beau Furn Mirror Mini-Suite Fi...
# 2                              Zen Life at the Beach
# 4    Hollywood Hills Zen Modern style Apt/Guesthouse
# 5    Tiny Home in Artistic Oasis near Venice and LAX
#
#                                          description  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  Run Runyon Canyon, Our Gym & Sauna Open <br />...
# 2  An oasis of tranquility awaits you.<br /><br /...
# 4  A very Modern Hollywood Hills Zen style galler...
# 5  Our home is located near Venice Beach without ...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Walk and run to Runyon Canyon, it is open!<br ...
# 2  This is the best part of Santa Monica. Quiet, ...
# 4  This is the famous Hollywood hills.. Historica...
# 5  Our neighborhood is very quiet and save. There...
#
#                                          picture_url  \
# 0  https://a0.muscache.com/pictures/4321499/1da98...
# 1  https://a0.muscache.com/pictures/miso/Hosting-...
# 2  https://a0.muscache.com/pictures/1082974/0f74c...
# 4  https://a0.muscache.com/pictures/5147dcd2-efad...
# 5  https://a0.muscache.com/pictures/7a29d275-f293...
#
#                               host_location  \
# 0  San Francisco, California, United States
# 1    Los Angeles, California, United States
# 2   Santa Monica, California, United States
# 4    Los Angeles, California, United States
# 5    Los Angeles, California, United States
#
#                                           host_about  host_response_time  \
# 0  Paolo Privitera, CEO Evensi\n\nPaolo, MIT MBA ...                 NaN
# 1  Writer.\r\nLiterary Manager.\r\nPhotographer.\...      within an hour
# 2  I have been teaching yoga and meditation for 3...      within an hour
# 4  Music Industry, Record producer, Songwriter, C...  within a few hours
# 5  we are loving our home and would like to share...  within a few hours
#
#    host_response_rate  host_acceptance_rate  ... review_scores_accuracy  \
# 0            0.909849              0.009098  ...                   5.00
# 1            1.000000              0.010000  ...                   4.77
# 2            1.000000              0.010000  ...                   4.45
# 4            1.000000              0.010000  ...                   4.04
# 5            1.000000              0.010000  ...                   4.88
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                      5.00                  3.00                        4.00
# 1                      4.90                  5.00                        4.97
# 2                      4.57                  4.65                        4.70
# 4                      3.83                  3.96                        4.30
# 5                      4.85                  4.91                        4.92
#
#   review_scores_location review_scores_value  reviews_per_month  \
# 0                   5.00                4.00               0.02
# 1                   5.00                4.84               0.71
# 2                   4.90                4.40               0.38
# 4                   4.64                4.00               0.41
# 5                   4.79                4.70               4.49
#
#    calendar_last_scrape days_of_relative_antiquity days_past_from_lastreview
# 0            2021-08-07                     3645.0                    1910.0
# 1            2021-08-07                     1317.0                      49.0
# 2            2021-08-07                     1667.0                     589.0
# 4            2021-08-07                     2078.0                       7.0
# 5            2021-08-07                     1436.0                      52.0
#
# [5 rows x 42 columns]

# %%
print(max(new_Airbnb_data_dates.days_of_relative_antiquity))
print(min(new_Airbnb_data_dates.days_of_relative_antiquity))
print(new_Airbnb_data_dates.days_of_relative_antiquity.describe())
# Out:
# 4336.0
# 1.0
# count    20142.000000
# mean       958.059974
# std        717.193975
# min          1.000000
# 25%        372.000000
# 50%        824.000000
# 75%       1419.000000
# max       4336.000000
# Name: days_of_relative_antiquity, dtype: float64

# %%
fig = plt.gcf()
fig.set_size_inches(8, 6)
sns.scatterplot(data=new_Airbnb_data_dates, x="price", y="days_of_relative_antiquity")
# Out:
# <AxesSubplot:xlabel='price', ylabel='days_of_relative_antiquity'>

# %%
fig = plt.gcf()
fig.set_size_inches(8, 6)
sns.scatterplot(data=new_Airbnb_data_dates, x="price", y="days_past_from_lastreview")
# Out:
# <AxesSubplot:xlabel='price', ylabel='days_past_from_lastreview'>

# %% [markdown]
# # price and host_is_superhost

# %%
df_test = new_Airbnb_data[['price', 'host_is_superhost']]
df_grp = df_test.groupby(['host_is_superhost'],as_index=True).mean()
df_grp
# Out:
#                         price
# host_is_superhost
# f                  229.064976
# t                  219.374961

# %%
sns.boxplot(x = 'price', y = "host_is_superhost", data=new_Airbnb_data)
# Out:
# <AxesSubplot:xlabel='price', ylabel='host_is_superhost'>

# %% [markdown]
# # host_response_time

# %%
host_response_time_df = new_Airbnb_data["host_response_time"].value_counts().to_frame()
host_response_time_df.index.name = "time"
host_response_time_df
# Out:
#                     host_response_time
# time
# within an hour                   15388
# within a few hours                4237
# within a day                      2510
# a few days or more                1374

# %%
fig = plt.gcf()
fig.set_size_inches(8,6)
sns.countplot(x="host_response_time",data = new_Airbnb_data,palette=sns.color_palette("husl", 8))
# Out:
# <AxesSubplot:xlabel='host_response_time', ylabel='count'>

# %% [markdown]
# # host_has_profile_pic

# %%
fig = plt.gcf()
# Change seaborn plot size
fig.set_size_inches(6, 4)
#sns.histplot(data=new_Airbnb_data, x='host_identity_verified',palette = sns.color_palette("tab10"),alpha = 1,shrink=.8)
sns.histplot(data=new_Airbnb_data, x='host_has_profile_pic', hue='host_has_profile_pic')
# Out:
# <AxesSubplot:xlabel='host_has_profile_pic', ylabel='Count'>

# %% [markdown]
# # ANOVA

# %% [markdown]
# ## Binarizamos

# %%
new_Airbnb_data.columns
#del new_Airbnb_data["review_scores_rating-binned"]
# Out:
# Index(['listing_url', 'name', 'description', 'neighborhood_overview',
#        'picture_url', 'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_picture_url', 'host_neighbourhood', 'host_has_profile_pic',
#        'host_identity_verified', 'neighbourhood_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'number_of_reviews', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'reviews_per_month'],
#       dtype='object')

# %%
bins =np.linspace(min(new_Airbnb_data["review_scores_cleanliness"]), max(new_Airbnb_data["review_scores_cleanliness"]),4)
bins
# Out:
# array([0.        , 1.66666667, 3.33333333, 5.        ])

# %%
group_names = ['Malo','Regular',"Excelente"]

# %%
new_Airbnb_data["review_scores_cleanliness_binned"]=pd.cut(new_Airbnb_data["review_scores_cleanliness"],bins,labels=group_names,include_lowest=True)

# %%
new_Airbnb_data[["review_scores_cleanliness","review_scores_cleanliness_binned"]].head(3)
# Out:
#    review_scores_cleanliness review_scores_cleanliness_binned
# 0                       5.00                        Excelente
# 1                       4.90                        Excelente
# 2                       4.57                        Excelente

# %%
new_Airbnb_data[["review_scores_cleanliness_binned","review_scores_rating"]].groupby(["review_scores_cleanliness_binned"]).size()
# Out:
# review_scores_cleanliness_binned
# Malo           153
# Regular        481
# Excelente    31424
# dtype: int64

# %%
fig = plt.gcf()
# Change seaborn plot size
fig.set_size_inches(6, 4)
sns.countplot(x="review_scores_cleanliness_binned",data = new_Airbnb_data)
# Out:
# <AxesSubplot:xlabel='review_scores_cleanliness_binned', ylabel='count'>

# %% [markdown]
# # P-Value

# %%
from scipy import stats

# %%
lista_variables =[ 'host_response_rate','host_acceptance_rate', 'bedrooms', 'beds', 'price','minimum_nights', 
                          'maximum_nights','number_of_reviews']

# %%
def coef_person(lista, y_variable='price'):
    pearson_corr_coef_list = []
    p_value_list = []
    for elem in lista:
        pearson_coef, p_value = stats.pearsonr(new_Airbnb_data[elem],new_Airbnb_data[y_variable])
        pearson_corr_coef_list.append(pearson_coef)
        p_value_list.append(p_value)
    return pearson_corr_coef_list,p_value_list

# %%
correlation_list,p_value_list = coef_person(lista_variables, y_variable='price')

# %%
df = pd.DataFrame(list(zip(lista_varibales,correlation_list,p_value_list)),
               columns =['varaible', 'Pearson_Correleation_coefficient','p-value'])
df
# Out:
#                varaible  Pearson_Correleation_coefficient       p-value
# 0  review_scores_rating                         -0.013432  1.617565e-02
# 1    host_response_rate                         -0.013432  1.617565e-02
# 2  host_acceptance_rate                          0.586534  0.000000e+00
# 3              bedrooms                          0.436439  0.000000e+00
# 4                  beds                          1.000000  0.000000e+00
# 5                 price                         -0.030652  4.035391e-08
# 6        minimum_nights                          0.026823  1.561486e-06
# 7        maximum_nights                         -0.069084  3.205293e-35

# %%
def determinar_relevancia_correlacion(p_value):
    if p_value < 0.001:
        status = "significant"
    else:
        if p_value <0.05:
            status = "moderate_significant"
        else:
            if p_value <0.1:
                status = "weak_significant"
            else:
                if p_value > 0.1:
                    status = "no_significant"
    return status

# %%
def aplicar_status(p_value_list):
    lista_status = []
    for p_value in p_value_list:
        lista_status.append(determinar_relevancia_correlacion(p_value))
    return lista_status

# %%
status_list = aplicar_status(p_value_list)

# %%
se = pd.Series(status_list)
df['status'] = se.values

# %%
df
# Out:
#                varaible  Pearson_Correleation_coefficient       p-value  \
# 0  review_scores_rating                         -0.013432  1.617565e-02
# 1    host_response_rate                         -0.013432  1.617565e-02
# 2  host_acceptance_rate                          0.586534  0.000000e+00
# 3              bedrooms                          0.436439  0.000000e+00
# 4                  beds                          1.000000  0.000000e+00
# 5                 price                         -0.030652  4.035391e-08
# 6        minimum_nights                          0.026823  1.561486e-06
# 7        maximum_nights                         -0.069084  3.205293e-35
#
#                  status
# 0  moderate_significant
# 1  moderate_significant
# 2           significant
# 3           significant
# 4           significant
# 5           significant
# 6           significant
# 7           significant

# %%
# Hacer lo mismo con review_score_rating

# %%
correlation_list,p_value_list = coef_person(lista_varibales, y_variable='review_scores_rating')

# %%
df = pd.DataFrame(list(zip(lista_varibales,correlation_list,p_value_list)),
               columns =['varaible', 'Pearson_Correleation_coefficient','p-value'])

# %%
status_list = aplicar_status(p_value_list)

# %%
se = pd.Series(status_list)
df['status'] = se.values

# %%
df
# Out:
#                        varaible  Pearson_Correleation_coefficient  \
# 0          review_scores_rating                          1.000000
# 1            host_response_rate                          0.105881
# 2          host_acceptance_rate                          0.105881
# 3                      bedrooms                          0.013643
# 4                          beds                          0.006569
# 5                         price                          0.018904
# 6                minimum_nights                         -0.018838
# 7                maximum_nights                         -0.035661
# 8             number_of_reviews                          0.111006
# 9     review_scores_cleanliness                          0.526064
# 10       review_scores_accuracy                          0.567017
# 11        review_scores_checkin                          0.486125
# 12  review_scores_communication                          0.526186
# 13       review_scores_location                          0.445146
# 14          review_scores_value                          0.566836
# 15            reviews_per_month                          0.070928
#
#          p-value                status
# 0   0.000000e+00           significant
# 1   1.395591e-80           significant
# 2   1.395591e-80           significant
# 3   1.457871e-02  moderate_significant
# 4   2.395341e-01        no_significant
# 5   7.119022e-04           significant
# 6   7.433004e-04           significant
# 7   1.693538e-10           significant
# 8   1.977400e-88           significant
# 9   0.000000e+00           significant
# 10  0.000000e+00           significant
# 11  0.000000e+00           significant
# 12  0.000000e+00           significant
# 13  0.000000e+00           significant
# 14  0.000000e+00           significant
# 15  4.883693e-37           significant

# %% [markdown]
# # ANOVA

# %%
fig = plt.gcf()
# Change seaborn plot size
fig.set_size_inches(12, 8)
sns.boxplot(x="review_scores_cleanliness_binned", y="review_scores_rating", data=new_Airbnb_data)
plt.grid()
plt.show()

# %%
grouped_test=new_Airbnb_data[["review_scores_cleanliness_binned","review_scores_rating"]].groupby(["review_scores_cleanliness_binned"])
grouped_test.size()
# Out:
# review_scores_cleanliness_binned
# Malo           153
# Regular        481
# Excelente    31424
# dtype: int64

# %%
counts = new_Airbnb_data["review_scores_cleanliness_binned"].value_counts()

# %%
counts
# Out:
# Excelente    31424
# Regular        481
# Malo           153
# Name: review_scores_cleanliness_binned, dtype: int64

# %%
for ind, k in enumerate(counts.keys()):
  plt.subplot(4, 1, ind+1)
  plt.title(k)
  plt.hist(new_Airbnb_data[new_Airbnb_data["review_scores_cleanliness_binned"] == k].review_scores_rating)
  plt.xlabel("score-rate")
  plt.ylabel("frequency")
  plt.show()

# %%
for k in counts.keys():
  mu = new_Airbnb_data[new_Airbnb_data["review_scores_cleanliness_binned"] == k].review_scores_rating.mean()
  sigma = new_Airbnb_data[new_Airbnb_data["review_scores_cleanliness_binned"] == k].review_scores_rating.std()
  print(f"{k:>2}: {mu:.4f} \u00B1 {sigma:.4f}")
# Out:
# Excelente: 4.7002 ± 0.5445
# Regular: 3.3235 ± 0.9797
# Malo: 1.4248 ± 0.9914

# %%
f_val, p_val = stats.f_oneway(grouped_test.get_group("Excelente")['review_scores_rating'], 
                              grouped_test.get_group('Regular')['review_scores_rating'],
                              grouped_test.get_group('Malo')['review_scores_rating'])
print("ANOVA results: F = ", f_val, ", P =", p_val)
# Out:
# ANOVA results: F =  4054.730861666196 , P = 0.0

# %%
from scipy.stats import shapiro

# %%
for k in counts.keys():
  stat, p = shapiro(new_Airbnb_data[new_Airbnb_data["review_scores_cleanliness_binned"] == k].review_scores_rating)
  print(f"Statistics for '{k}'= {stat:.3f}, p={p:.3f}")
  if p > 0.05:
    print('\tSample looks Gaussian')
  else:
    print('\tSample does not look Gaussian')
# Out:
# Statistics for 'Excelente'= 0.402, p=0.000
# 	Sample does not look Gaussian
# Statistics for 'Regular'= 0.937, p=0.000
# 	Sample does not look Gaussian
# Statistics for 'Malo'= 0.490, p=0.000
# 	Sample does not look Gaussian

# %%
new_Airbnb_data.columns
# Out:
# Index(['listing_url', 'name', 'description', 'neighborhood_overview',
#        'picture_url', 'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_picture_url', 'host_neighbourhood', 'host_has_profile_pic',
#        'host_identity_verified', 'neighbourhood_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'number_of_reviews', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'reviews_per_month',
#        'review_scores_cleanliness_binned'],
#       dtype='object')

# %% [markdown]
# #  Análisis de datos geográficos

# %%
new_Airbnb_data.plot(kind="scatter", x="", y="latitude", alpha=0.4,
    s=Airbnb_data["number_of_reviews"], label="number_of_reviews", figsize=(10,7),
    c="price", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()

# %%
Airbnb_data.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
    s=Airbnb_data["number_of_reviews"], label="number_of_reviews", figsize=(10,7),
    c="price", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()

# %%
new_Airbnb_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31767 entries, 0 to 32239
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listing_url                  31767 non-null  object
#  1   name                         31765 non-null  object
#  2   description                  30698 non-null  object
#  3   neighborhood_overview        19599 non-null  object
#  4   picture_url                  31767 non-null  object
#  5   host_location                31655 non-null  object
#  6   host_about                   19122 non-null  object
#  7   host_response_time           23258 non-null  object
#  8   host_response_rate           23258 non-null  object
#  9   host_acceptance_rate         23458 non-null  object
#  10  host_is_superhost            31726 non-null  object
#  11  host_picture_url             31726 non-null  object
#  12  host_neighbourhood           25520 non-null  object
#  13  host_has_profile_pic         31726 non-null  object
#  14  host_identity_verified       31726 non-null  object
#  15  neighbourhood                19599 non-null  object
#  16  latitude                     31767 non-null  float64
#  17  longitude                    31767 non-null  float64
#  18  property_type                31767 non-null  object
#  19  room_type                    31767 non-null  object
#  20  accommodates                 31767 non-null  int64
#  21  bathrooms_text               31725 non-null  object
#  22  bedrooms                     28090 non-null  float64
#  23  beds                         31148 non-null  float64
#  24  amenities                    31767 non-null  object
#  25  price                        31767 non-null  float64
#  26  minimum_nights               31767 non-null  int64
#  27  maximum_nights               31767 non-null  int64
#  28  number_of_reviews            31767 non-null  int64
#  29  first_review                 24064 non-null  object
#  30  last_review                  24064 non-null  object
#  31  review_scores_rating         24064 non-null  float64
#  32  review_scores_accuracy       23737 non-null  float64
#  33  review_scores_cleanliness    23738 non-null  float64
#  34  review_scores_checkin        23729 non-null  float64
#  35  review_scores_communication  23736 non-null  float64
#  36  review_scores_location       23726 non-null  float64
#  37  review_scores_value          23724 non-null  float64
#  38  reviews_per_month            24064 non-null  float64
# dtypes: float64(13), int64(4), object(22)
# memory usage: 9.7+ MB

# %% [markdown]
# # Análisis de Imágenes

# %%
# cuántas fotos tenemos
len(Airbnb_data['picture_url'])
# Out:
# 32240

# %%
from PIL import Image
import requests
from io import BytesIO

IMAGE_SIZE = [224,224]

response = requests.get(Airbnb_data['picture_url'][4])
img = Image.open(BytesIO(response.content)).resize(IMAGE_SIZE)
plt.imshow(img)

# %%
Airbnb_data['picture_url'][4]
# Out:
# 'https://a0.muscache.com/pictures/5147dcd2-efad-495c-8c31-d781cc626878.jpg'

# %%
popular['picture_url'][1190]
# Out:
# 'https://a0.muscache.com/pictures/b12d69ec-02bb-4f51-b5cf-c060e57271f7.jpg'

# %%
popular = new_Airbnb_data_dates[new_Airbnb_data_dates["number_of_reviews"]==915]
popular["picture_url"]
response = requests.get(popular['picture_url'][1190])
img = Image.open(BytesIO(response.content)).resize(IMAGE_SIZE)
plt.imshow(img)

# %%
import colorgram

rgb_colors = []
colors = colorgram.extract(img, 30)
for color in colors:
    r = color.rgb.r
    g = color.rgb.g
    b = color.rgb.b
    new_color = (r, g, b)
    rgb_colors.append(new_color)

print(rgb_colors)
print(len(rgb_colors))
# Out:
# [(69, 23, 6), (203, 156, 123), (144, 88, 48), (238, 211, 186), (114, 48, 18), (31, 2, 4), (180, 120, 71), (110, 59, 11), (224, 188, 156), (169, 117, 89), (65, 75, 91), (92, 77, 83), (220, 185, 164), (41, 54, 70), (162, 146, 151), (75, 58, 61), (51, 60, 77), (161, 156, 167), (200, 185, 186)]
# 19

# %%
Airbnb_data.price[4]
# Out:
# 118.0

# %%
spikes = np.random.random(100)
plt.eventplot(spikes, orientation='horizontal', linelengths=0.9, color = [(.69, .23, .6)])

plt.show()

# %%
import turtle as turtle_module
import random

colours = rgb_colors
tim = turtle_module.Turtle()
turtle_module.colormode(255)
tim.speed("fastest")
tim.hideturtle()

def initial_position():
    tim.penup()
    tim.setheading(225)
    tim.forward(300)
    tim.setheading(0)

initial_position()

def move_right():
    for _ in range(10):
        tim.dot(20)
        tim.penup()
        tim.forward(50)
        tim.pencolor(random.choice(colours))


def move_left():
    tim.dot(20)
    tim.penup()
    tim.forward(-500)


def move_up():
    tim.setheading(90)
    tim.dot(20)
    tim.penup()
    tim.forward(50)
    tim.setheading(0)


for play in range(10):
    move_right()
    move_left()
    move_up()

screen = turtle_module.Screen()
screen.exitonclick()
